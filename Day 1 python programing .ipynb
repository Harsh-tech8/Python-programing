# %%
print("hello i am harsh")
# Out:
# hello i am harsh

# %%
x = "Harsh"

# %%
print(x)
# Out:
# Harsh

# %%
Y = 45

# %%
print(Y)
# Out:
# 45

# %%
type(x)
# Out:
# str

# %%
type(Y)
# Out:
# int

# %%
# singal line comment 
"""
Multiple 
line 
comment
"""
# Out:
# '\nMultiple \nline \ncomment\n'

# %%
name  = input("enter your name :")

# %%
type (name)

# %%
print(name)

# %%
mod = input("enter the num :")

# %%
type(mod)

# %%
mod = int(input("enter number:"))

# %%
type(mod)

# %%
print(f"your name is {name}")
