# %% [markdown]
# ## Comparision operator

# %%
a = 10
b = 20

# %%
a > b
# Out:
# False

# %%
a  <  b
# Out:
# True

# %%
a != b
# Out:
# True

# %%
a == b
# Out:
# False

# %%
a <= b
# Out:
# True

# %%
a >= b
# Out:
# False

# %% [markdown]
# ## Logical opertor

# %%
 a > b and a < b and a == b
# Out:
# False

# %%
 a > b or a < b or a == b
# Out:
# True

# %%
not a == b
# Out:
# True

# %%
username = "root"

# %%
password = "harsh12"

# %%
user = input("enter user name :")
# Out:
# enter user name : root

# %%
passwordd = input("enter password:")
# Out:
# enter password: harsh12

# %%
if username == user and password == passwordd:
    print ("user name and password is correct!! ")
else :
    print("enter correct pass and user name")
# Out:
# user name and password is correct!!

# %% [markdown]
# ## Assingment operators

# %%
x = 10

# %%
x += 5
print(x)
# Out:
# 15

# %%
x *= 5

# %%
print(x)
# Out:
# 75

# %%
y = 4

# %%
y /= 10

# %%
print(y)
# Out:
# 0.4

# %% [markdown]
# ## Membersip operator

# %%
name = "python"

# %%
"p" in name
# Out:
# True

# %%
"X" not in name
# Out:
# True

# %%
allowed_user = ["jack","tom","you"]

user_name = input("enter user name:")

if user_name in allowed_user :
    print("yes you are a current usser !!")
else :
    print("not in user list")
# Out:
# enter user name: jack
# yes you are a current usser !!

# %% [markdown]
# ## Identity operator

# %%
a =10,20,30

# %%
b = a

# %%
c = 10,20,30

# %%
id(a)
# Out:
# 2959670180160

# %%
id(b)
# Out:
# 2959670180160

# %%
if id(a) == id(b):
    print("*******")
else :
    print("######")
# Out:
# *******
