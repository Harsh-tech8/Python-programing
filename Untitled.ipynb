# %%
name = input("enter your name :")
age  = int (input ("enter your age is:"))

if age >= 18:
    print(f"{name} can vote ")
else :
    print ("he or she can't vote ")
# Out:
# enter your name : harsh
# enter your age is: 78
# harsh can vote

# %%
name = input("enter your name :")
marks = int (input ("enter tour marks :"))

if marks >= 55:
    print (f"hey,{name} you are pass 🎉🎉🎉🎃")
else :
    print ("you are fail :( ")
# Out:
# enter your name : Harsh Vardhan nagavan
# enter tour marks : 76
# hey,Harsh Vardhan nagavan you are pass 🎉🎉🎉🎃

# %%
name = input("enter your name :")
marks = int (input ("enter tour marks :"))

if marks >= 90:
    print (f"{name} got a nice work grade A+")
elif marks >= 80:
     print (f"{name} got a good grade A")
elif marks >= 70:
     print (f"{name} got a good grade B+")
elif marks >= 60:
     print (f"{name} got a good grade C")
elif marks >= 50:
     print (f"{name} got a not good grade C+")
elif marks >= 40:
     print (f"{name} got a not good grade D ")
else :
    print ('you are fail')
# Out:
# enter your name : Harsh Vardhan nagavan
# enter tour marks : 66
# Harsh Vardhan nagavangot a good grade C

# %%
first_name = "Harsh"
sec_name = "nagavan"

# %%
name = (first_name+" "+sec_name).upper()
print(name)
# Out:
# HARSH NAGAVAN

# %%
len(name)
# Out:
# 13

# %%
print(name.capitalize())
# Out:
# Harsh nagavan

# %%
print ("Welcome to my basic calculalter ")

num1 = int (input("enter your first number :"))
num2 = int (input("enter your sec number :"))

print ("""
1.Add
2.sub
3.multi
4.divied 
5.exit 
""")

choice = int (input ("enter your choice"))

if choice == 1:
 sum = num1+num2
 print(f"sum is: {sum}")
elif choice == 2:
 sub = num1-num2
 print(f"diff is: {sub}")
elif choice == 3:
 sub = num1*num2
 print(f"multiplecation is: {sub}")
elif choice == 4:
 sub = num1/num2
 print(f"division is: {sub}")
else :
 print ("enter a vaild choice ")
# Out:
# Welcome to my basic calculalter
# enter your first number : 55
# enter your sec number : 3
# 1.Add
# 2.sub
# 3.multi
# 4.divied
# 5.exit
# enter your choice 3
# multiplecation is: 165

# %%
print ("Welcome to my cal ")

print("""

1.Area Square.
2.Area Rectangle.
3.Area Triangle.
4.Area Circle.

""")

choice = int (input("enter your choice:"))
if choice == 1:
 s = int(input("enter the side "))
 
 area = s*s
 print(f"area of Square is:{area}")

elif choice == 2:
    len = int(input("enter the length "))
    wdt = int(input("enter the width "))
    area = len * wdt
    printf(f"area of Rectangle is: {area}")
 
elif choice == 3:
    base = int(input("enter the base "))
    hth = int (input("enter the height"))
    area = 1/2(base * hth)
    print(f"area of Triangle is :{area}")
 
elif choice == 4:
    pie = 3.14
    radis = int(input ("enter the radius "))
    area = pie*r^2
    print(f"area of crile is :{area}")
 
else :
 print ("enter a vaild choice ")
# Out:
# Welcome to my cal
#
#
# 1.Area Square.
# 2.Area Rectangle.
# 3.Area Triangle.
# 4.Area Circle.
# enter your choice: 1
# enter the side  6
# area of Square is:36
