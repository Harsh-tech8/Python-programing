# %% [markdown]
# ## Modules

# %%
import math

# %%
math.sqrt(12)
# Out:
# 3.4641016151377544

# %%
math.pow(12,2)
# Out:
# 144.0

# %%
math.factorial(10)
# Out:
# 3628800

# %%
import random

# %%
while True:
   Bot = random.randint(1,10)
   print("-"*20)
   print("Number gussing game ")
   print("-"*20)
   user_choice = input("enter any number (1-10):")

   if user_choice == Bot :
       print ("you win !!@#")
   elif user_choice == 0 or user_choice == "e":
       break
   else :
       print(f"Bot choice is {Bot}")
       print("you lose try again ")
# Out:
# --------------------
# Number gussing game
# --------------------
# enter any number (1-10): 0
# Bot choice is 10
# you lose try again
# --------------------
# Number gussing game
# --------------------

# %%
import time

# %%
print(time.time())
# Out:
# 1790174115.51343

# %%
time.sleep(3)

# %%
mass = ("Welcome to python world").upper()

# %%
for char in mass:
    print(char , end= " ",flush=True)
    time.sleep(0.1)
# Out:
# W E L C O M E   T O   P Y T H O N   W O R L D

# %%
1.how to sand what,s up/email/text maasage using python
2.how to post on linkedin / insta using py
3.how to screap any data form a web site using py
4.how to create a telegram bot using py 
5.hoe to cheak wether info using py 
5.how to cheak the states of aweb site using py 
6.using py make a random password have using py
7.search on google/you tube using py
8.how to convert voice to text
9.text to voice
