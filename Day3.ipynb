# %% [markdown]
# list

# %%
list = ["rahul","harsh","mohit","lost"]

# %%
type(list)
# Out:
# list

# %%
print(list)
# Out:
# ['rahul', 'harsh', 'mohit', 'lost']

# %%
print(list[3])
# Out:
# lost

# %%
student = ["harsh",12345678,87.8,"good student ",True]

# %%
type(student)
# Out:
# list

# %%
print (student)
# Out:
# ['harsh', 12345678, 87.8, 'good student ', True]

# %%
print(student[-3])
# Out:
# 87.8

# %%
print(student[3])
# Out:
# good student

# %%
len(student)
# Out:
# 5

# %%
student[2] = 66.7
student[3] = "not more good"

# %%
print(student)
# Out:
# ['harsh', 12345678, 66.7, 'not more good', True]

# %%
student.append("jaipur")

# %%
print(student)
# Out:
# ['harsh', 12345678, 66.7, 'not more good', True, 'jaipur']

# %%
student.insert(1,"cse(ds)")

# %%
print(student)
# Out:
# ['harsh', 'cse(ds)', 12345678, 66.7, 'not more good', True, 'jaipur']

# %%
student.remove(True)

# %%
print(student)
# Out:
# ['harsh', 'cse(ds)', 12345678, 66.7, 'not more good', 'jaipur']

# %%
student.reverse()

# %%
print(student)
# Out:
# ['jaipur', 'not more good', 66.7, 12345678, 'cse(ds)', 'harsh']

# %%
list.append("harsh")

# %%
list.append("harsh")

# %%
print(list)
# Out:
# ['rahul', 'mohit', 'lost', 'harsh', 'harsh', 'harsh']

# %%
list.remove("harsh")

# %%
print(list)
# Out:
# ['rahul', 'mohit', 'lost', 'harsh', 'harsh']

# %%
list.count("harsh")
# Out:
# 2

# %%
list.index("harsh")
# Out:
# 3

# %%
iteam = ["keyboard","mointer","charger","laptop"]

need = input("enter a iteam which you need:")

if need  in iteam :
    print("iteam is found")
else :
    print("not found")
# Out:
# enter a iteam which you need: laptop
# iteam is found

# %%
iteam.sort()

# %%
print(iteam)
# Out:
# ['charger', 'keyboard', 'laptop', 'mointer']

# %%
marks = [87,98,76,45,99,19]

# %%
marks.sort()

# %%
print(marks)
# Out:
# [19, 45, 76, 87, 98, 99]

# %%
print("max marks :",max(marks))
print("min marks :",min(marks))
print("total marks :",sum(marks))
# Out:
# max marks : 99
# min marks : 19
# total marks : 424

# %% [markdown]
# Tuple

# %%
t1 = (12,34,56,76)

# %%
print(t1)
# Out:
# (12, 34, 56, 76)

# %%
t1.count(34)
# Out:
# 1

# %%
t1.index(12)
# Out:
# 0

# %%
name = ("hey ","harsh","rock","yesh",1,2,3,4)

# %%
print(name)
# Out:
# ('hey ', 'harsh', 'rock', 'yesh', 1, 2, 3, 4)
