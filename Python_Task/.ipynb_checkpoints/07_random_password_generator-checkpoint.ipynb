# %% [markdown]
# # 07 Random Password Generator

# %%
"""
07 - Secure random password generator

No installation required.
Uses Python's 'secrets' module, which is designed for security-sensitive
random values.
"""

# %%
import secrets
import string


def generate_password(length=16):
    if length < 8:
        raise ValueError("Use a password length of at least 8 characters.")

    alphabet = string.ascii_letters + string.digits + string.punctuation
    return "".join(secrets.choice(alphabet) for _ in range(length))


if __name__ == "__main__":
    try:
        length = int(input("Password length (default 16): ") or "16")
        password = generate_password(length)

        print("\nGenerated password:")
        print(password)

    except ValueError as error:
        print("Error:", error)
# Out:
# Password length (default 16):  Harsh nagavan@1238
# Error: invalid literal for int() with base 10: 'Harsh nagavan@1238'
