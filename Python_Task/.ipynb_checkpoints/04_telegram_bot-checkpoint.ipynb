# %% [markdown]
# # 04 Telegram Bot

# %%
"""
04 - Telegram bot using Python

Install:
    pip install python-telegram-bot

Create a bot with BotFather on Telegram and copy its bot token.
"""

# %%
import nest_asyncio
import asyncio
from telegram import Update
from telegram.ext import ApplicationBuilder, CommandHandler, ContextTypes

# Apply nest_asyncio to allow nested event loops in Jupyter
nest_asyncio.apply()

BOT_TOKEN = "PUT_YOUR_BOT_TOKEN_HERE"

async def start(update: Update, context: ContextTypes.DEFAULT_TYPE):
    await update.message.reply_text("Hello! I am your Python Telegram bot.")

async def hello(update: Update, context: ContextTypes.DEFAULT_TYPE):
    await update.message.reply_text("Hello from Python!")

def main():
    app = ApplicationBuilder().token(BOT_TOKEN).build()

    app.add_handler(CommandHandler("start", start))
    app.add_handler(CommandHandler("hello", hello))

    print("Bot is running...")
    app.run_polling()

if __name__ == "__main__":
    main()
# Out:
# Bot is running...
# Network Retry Loop (Bootstrap Initialize Application): Invalid token. Aborting retry loop.
# Traceback (most recent call last):
#   File "C:\ano\Lib\site-packages\telegram\_bot.py", line 865, in initialize
#     await self.get_me()
#   File "C:\ano\Lib\site-packages\telegram\ext\_extbot.py", line 2040, in get_me
#     return await super().get_me(
#            ^^^^^^^^^^^^^^^^^^^^^
#     ...<5 lines>...
#     )
#     ^
#   File "C:\ano\Lib\site-packages\telegram\_bot.py", line 1005, in get_me
#     result = await self._post(
#              ^^^^^^^^^^^^^^^^^
#     ...<6 lines>...
#     )
#     ^
#   File "C:\ano\Lib\site-packages\telegram\_bot.py", line 712, in _post
#     return await self._do_post(
#            ^^^^^^^^^^^^^^^^^^^^
#     ...<6 lines>...
#     )
#     ^
#   File "C:\ano\Lib\site-packages\telegram\ext\_extbot.py", line 378, in _do_post
#     return await super()._do_post(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#     ...<6 lines>...
#     )
#     ^
# ...
